# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/19O4w8F-wQ3BqszS0K6Dn2GCG_Z4SLiIO)
#
# In this notebook, we will explore stock price prediction using three methods:
#
# * Linear Regression using $L_2$ regularization or Ridge Regression
# * Gradient Boosting Regressors
# * Neural Network based approaches using 1D Convolutions, LSTM layers with a Huber loss
#
# The source of the stock prices is from https://finance.yahoo.com/quote/TSLA/history?p=TSLA where I downloaded all of the stock prices for Tesla Inc. since they become a publicly traded company up until today's date (September 1st, 2019).  The variable to predict is the **Adjusted Close** price.
#
# If you are running this on Google Colab, please make sure you switch the runtime to GPU so when you run the cells using neural networks, it will train much faster.

# %% [markdown]
# First let's import all of the necessary packages we need, which include NumPy, Pandas, Matplotlib, Scikit-learn and Keras/Tensorflow.

# %%
# Import necessary packages
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Dense
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import Huber
from keras.optimizers import SGD
# Out:
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/prudhvi/Devtools/envs/pyml/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# I have exported the Tesla stock price data to my personal Dropbox and will be downloading it locally.

# %%
# Download the data and store it
# Tesla stock since the beginning
# !wget -O tesla.csv https://www.dropbox.com/s/na2vurooejpew59/TSLA.csv?dl=1
# Out:
# --2019-09-02 17:24:00--  https://www.dropbox.com/s/na2vurooejpew59/TSLA.csv?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.1, 2620:100:6030:1::a27d:5001
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/na2vurooejpew59/TSLA.csv [following]
# --2019-09-02 17:24:00--  https://www.dropbox.com/s/dl/na2vurooejpew59/TSLA.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucda0e40626d2b54f5c35935829e.dl.dropboxusercontent.com/cd/0/get/Anzgt1Og_-tQFueMJNi45Lp7FUkRvr6XkA4K6Rh2f31r7C-FrQFZvKtN-wwSBCJxSZwU8M1nkgTk21ds_tKp22EDEjdskJNAOzEOopSotOpfhqGMSv30VHN7k_CQhJkujUM/file?dl=1# [following]
# --2019-09-02 17:24:00--  https://ucda0e40626d2b54f5c35935829e.dl.dropboxusercontent.com/cd/0/get/Anzgt1Og_-tQFueMJNi45Lp7FUkRvr6XkA4K6Rh2f31r7C-FrQFZvKtN-wwSBCJxSZwU8M1nkgTk21ds_tKp22EDEjdskJNAOzEOopSotOpfhqGMSv30VHN7k_CQhJkujUM/file?dl=1
# Resolving ucda0e40626d2b54f5c35935829e.dl.dropboxusercontent.com (ucda0e40626d2b54f5c35935829e.dl.dropboxusercontent.com)... 162.125.80.6, 2620:100:6030:6::a27d:5006
# Connecting to ucda0e40626d2b54f5c35935829e.dl.dropboxusercontent.com (ucda0e40626d2b54f5c35935829e.dl.dropboxusercontent.com)|162.125.80.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167196 (163K) [application/binary]
# Saving to: ‘tesla.csv’
#
# tesla.csv           100%[===================>] 163.28K   384KB/s    in 0.4s
#
# 2019-09-02 17:24:02 (384 KB/s) - ‘tesla.csv’ saved [167196/167196]

# %% [markdown]
# Use Pandas to read in the data and set the independent variable to be the *Date*.  Let's also take a look at the first few entries

# %%
df = pd.read_csv('tesla.csv')

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                  Open   High        Low      Close  Adj Close    Volume
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %% [markdown]
# Let's take a look at how the prices looks like each day since the beginning up to this point with the date on the x-axis and the price on the y-axis.

# %%
df['Adj Close'].plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# To make this more robust to noise and to leverage past values, we will not use the date to predict the stock prices, but we will use batches of 32 prices where each training example, we leverage 32 prices from the past to predict the price on the 33rd day.  We will thus have $N - 32$ training examples with $N$ being the number of days we've downloaded for the stock data.  We will thus create a 2D matrix of training samples with each row being the prices 32 consecutive days in the past with the price to predict being the current day.

# %%
window_size = 32 # Allow us to look at 32 days into the past
# Prepare the data so that we have 32 day windows and predict what the next day should be

# Get indices of access for the data
num_samples = len(df) - window_size
indices = np.arange(num_samples).astype(np.int)[:,None] + np.arange(window_size + 1).astype(np.int)

# %%
data = df['Adj Close'].values[indices] # Create the 2D matrix of training samples

# %% [markdown]
# We create a 2D matrix such that we have 33 columns per example.  The training samples will be the first 32 columns with the target variable being the last column.

# %%
X = data[:,:-1] # Each row represents 32 days in the past
y = data[:,-1] # Each output value represents the 33rd day

# %% [markdown]
# Perform train/test split such that the first 80% of the prices is the training set and the last 20% of the prices is the test dataset.  We will train on the training set and test the performance on the test set to see how well we can forecast the price for Tesla stock.

# %%
# Train and test split
split_fraction = 0.8
ind_split = int(split_fraction * num_samples)
X_train = X[:ind_split]
y_train = y[:ind_split]
X_test = X[ind_split:]
y_test = y[ind_split:]

# %% [markdown]
# # Method #1 - Ridge Regression
#
# We will use the Ridge Regression method from Scikit-learn where we'll train and perform inference on the training and test data respectively.  Let's also plot how it compares with the actual data for both training and test.

# %%
# Train
ridge_model = Ridge()
ridge_model.fit(X_train, y_train)

# Infer
y_pred_train_ridge = ridge_model.predict(X_train)
y_pred_ridge = ridge_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_ridge['Adj Close Train'] = y_pred_train_ridge[:-window_size]
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# OK... not bad and very frighteningly close.  We may be overfitting.  Let's check out the test data.

# %%
# Same for the test
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_ridge['Adj Close Test'] = y_pred_ridge
df_ridge.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Wow... ok let's move on.
#
# # Method #2 - Gradient Boosting Trees
#
# Let's apply the same methodology from Method #1 to Gradient Boosting Trees in Scikit-learn.

# %%
# Model #2 - Gradient Boosting Trees
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)

# Infer
y_pred_train_gb = gb_model.predict(X_train)
y_pred_gb = gb_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_gb['Adj Close Train'] = y_pred_train_gb[:-window_size]
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again... frighteningly similar.  Let's check the test data.

# %%
# Same for the test
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_gb['Adj Close Test'] = y_pred_gb
df_gb.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# The results here make sense.  Since trees performing majority voting so there's no interpolation involved, we can see at points of high curvature, it doesn't do so well but the general trend is correct.
#
# # Method #3 - Using neural networks with 1D convolutional and LSTM layers
#
# The last method we'll use is a neural network based one using Keras / Tensorflow.  We use a stack of Conv1D and LSTM layers, followed by Dense layers lastly followed by a linear layer to predict the stock price.

# %%
# Model #3 - Using RNNs
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])

keras_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0902 17:24:11.375235 139876865906560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0902 17:24:11.412709 139876865906560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0902 17:24:11.419697 139876865906560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 32, 128)           768
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 128)           82048
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32, 128)           131584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 358,465
# Trainable params: 358,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This is a technique to find the optimal learning rate for the neural network.  Specifically we gradually increase the learning rate at each epoch, recording the loss for each then choosing the learning rate that has the smallest loss overall.
#
# Also, neural networks learn better when the data is normalized so we will normalize the data to the $[-1,1]$ range by using Scikit-learn's `MinMaxScaler`.  Therefore, we need to find apply this scaling on all of the price data, then decompose it into the training and test sets again.

# %%
# First figure out the right learning rate
lr_schedule = LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = SGD(lr=1e-8, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
# Scale the data due to LSTM units
scaler = MinMaxScaler(feature_range=(-1, 1))
data_transform = scaler.fit_transform(df['Adj Close'].values[:,None])
data_transform = data_transform[indices]
X2 = data_transform[:,:-1]
y2 = data_transform[:,-1]
X_train_reshape = X2[:ind_split]
y_train_reshape = y2[:ind_split]
X_test_reshape = X2[ind_split:]
y_test_reshape = y2[ind_split:]
# Out:
# W0902 17:24:12.389597 139876865906560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# We now try and find the optimal learning rate.  If you're using Google Colab, this will take ~4 minutes.

# %%
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, callbacks=[lr_schedule], validation_data=(X_test_reshape, y_test_reshape))
# Out:
# W0902 17:24:13.623549 139876865906560 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0902 17:24:14.762250 139876865906560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0902 17:24:14.815246 139876865906560 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 1822 samples, validate on 456 samples
# Epoch 1/250
# 1822/1822 [==============================] - 9s 5ms/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 2/250
# 1822/1822 [==============================] - 1s 456us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 3/250
# 1822/1822 [==============================] - 1s 450us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 4/250
# 1822/1822 [==============================] - 1s 452us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 5/250
# 1822/1822 [==============================] - 1s 458us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 6/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 7/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 8/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 9/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 10/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.2090 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 11/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.2089 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 12/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 0.2089 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 13/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.2089 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 14/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.2089 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 15/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.2089 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 16/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.2089 - mean_absolute_error: 0.5227 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 17/250
# 1822/1822 [==============================] - 1s 454us/step - loss: 0.2089 - mean_absolute_error: 0.5226 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 18/250
# 1822/1822 [==============================] - 1s 460us/step - loss: 0.2089 - mean_absolute_error: 0.5226 - val_loss: 0.1674 - val_mean_absolute_error: 0.5290
# Epoch 19/250
# 1822/1822 [==============================] - 1s 452us/step - loss: 0.2089 - mean_absolute_error: 0.5226 - val_loss: 0.1673 - val_mean_absolute_error: 0.5290
# Epoch 20/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.2089 - mean_absolute_error: 0.5226 - val_loss: 0.1673 - val_mean_absolute_error: 0.5290
# Epoch 21/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.2088 - mean_absolute_error: 0.5226 - val_loss: 0.1673 - val_mean_absolute_error: 0.5290
# Epoch 22/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.2088 - mean_absolute_error: 0.5226 - val_loss: 0.1673 - val_mean_absolute_error: 0.5290
# Epoch 23/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.2088 - mean_absolute_error: 0.5225 - val_loss: 0.1673 - val_mean_absolute_error: 0.5290
# Epoch 24/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.2088 - mean_absolute_error: 0.5225 - val_loss: 0.1673 - val_mean_absolute_error: 0.5290
# Epoch 25/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.2087 - mean_absolute_error: 0.5225 - val_loss: 0.1673 - val_mean_absolute_error: 0.5290
# Epoch 26/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 0.2087 - mean_absolute_error: 0.5224 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 27/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.2087 - mean_absolute_error: 0.5224 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 28/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.2086 - mean_absolute_error: 0.5224 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 29/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.2086 - mean_absolute_error: 0.5223 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 30/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.2085 - mean_absolute_error: 0.5223 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 31/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 0.2085 - mean_absolute_error: 0.5222 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 32/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.2084 - mean_absolute_error: 0.5221 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 33/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.2083 - mean_absolute_error: 0.5221 - val_loss: 0.1673 - val_mean_absolute_error: 0.5289
# Epoch 34/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 0.2083 - mean_absolute_error: 0.5220 - val_loss: 0.1672 - val_mean_absolute_error: 0.5289
# Epoch 35/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.2082 - mean_absolute_error: 0.5219 - val_loss: 0.1672 - val_mean_absolute_error: 0.5288
# Epoch 36/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.2081 - mean_absolute_error: 0.5218 - val_loss: 0.1672 - val_mean_absolute_error: 0.5288
# Epoch 37/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 0.2080 - mean_absolute_error: 0.5217 - val_loss: 0.1672 - val_mean_absolute_error: 0.5288
# Epoch 38/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 0.2078 - mean_absolute_error: 0.5215 - val_loss: 0.1672 - val_mean_absolute_error: 0.5288
# Epoch 39/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.2077 - mean_absolute_error: 0.5214 - val_loss: 0.1671 - val_mean_absolute_error: 0.5287
# Epoch 40/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.2075 - mean_absolute_error: 0.5212 - val_loss: 0.1671 - val_mean_absolute_error: 0.5287
# Epoch 41/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.2073 - mean_absolute_error: 0.5210 - val_loss: 0.1671 - val_mean_absolute_error: 0.5287
# Epoch 42/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.2071 - mean_absolute_error: 0.5208 - val_loss: 0.1670 - val_mean_absolute_error: 0.5286
# Epoch 43/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.2069 - mean_absolute_error: 0.5205 - val_loss: 0.1670 - val_mean_absolute_error: 0.5286
# Epoch 44/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.2067 - mean_absolute_error: 0.5203 - val_loss: 0.1670 - val_mean_absolute_error: 0.5285
# Epoch 45/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.2064 - mean_absolute_error: 0.5200 - val_loss: 0.1669 - val_mean_absolute_error: 0.5285
# Epoch 46/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.2061 - mean_absolute_error: 0.5196 - val_loss: 0.1668 - val_mean_absolute_error: 0.5284
# Epoch 47/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.2057 - mean_absolute_error: 0.5193 - val_loss: 0.1668 - val_mean_absolute_error: 0.5283
# Epoch 48/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.2053 - mean_absolute_error: 0.5188 - val_loss: 0.1667 - val_mean_absolute_error: 0.5282
# Epoch 49/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.2049 - mean_absolute_error: 0.5184 - val_loss: 0.1666 - val_mean_absolute_error: 0.5281
# Epoch 50/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.2044 - mean_absolute_error: 0.5179 - val_loss: 0.1665 - val_mean_absolute_error: 0.5280
# Epoch 51/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.2039 - mean_absolute_error: 0.5173 - val_loss: 0.1664 - val_mean_absolute_error: 0.5279
# Epoch 52/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.2032 - mean_absolute_error: 0.5166 - val_loss: 0.1663 - val_mean_absolute_error: 0.5277
# Epoch 53/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.2025 - mean_absolute_error: 0.5159 - val_loss: 0.1662 - val_mean_absolute_error: 0.5276
# Epoch 54/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.2018 - mean_absolute_error: 0.5150 - val_loss: 0.1660 - val_mean_absolute_error: 0.5274
# Epoch 55/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.2009 - mean_absolute_error: 0.5141 - val_loss: 0.1659 - val_mean_absolute_error: 0.5273
# Epoch 56/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.1999 - mean_absolute_error: 0.5131 - val_loss: 0.1657 - val_mean_absolute_error: 0.5271
# Epoch 57/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.1988 - mean_absolute_error: 0.5119 - val_loss: 0.1655 - val_mean_absolute_error: 0.5268
# Epoch 58/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.1976 - mean_absolute_error: 0.5106 - val_loss: 0.1652 - val_mean_absolute_error: 0.5265
# Epoch 59/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.1963 - mean_absolute_error: 0.5091 - val_loss: 0.1650 - val_mean_absolute_error: 0.5262
# Epoch 60/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.1948 - mean_absolute_error: 0.5075 - val_loss: 0.1647 - val_mean_absolute_error: 0.5258
# Epoch 61/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.1932 - mean_absolute_error: 0.5057 - val_loss: 0.1643 - val_mean_absolute_error: 0.5254
# Epoch 62/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.1914 - mean_absolute_error: 0.5037 - val_loss: 0.1639 - val_mean_absolute_error: 0.5249
# Epoch 63/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.1893 - mean_absolute_error: 0.5014 - val_loss: 0.1635 - val_mean_absolute_error: 0.5243
# Epoch 64/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.1871 - mean_absolute_error: 0.4990 - val_loss: 0.1630 - val_mean_absolute_error: 0.5237
# Epoch 65/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.1846 - mean_absolute_error: 0.4962 - val_loss: 0.1624 - val_mean_absolute_error: 0.5230
# Epoch 66/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.1819 - mean_absolute_error: 0.4931 - val_loss: 0.1618 - val_mean_absolute_error: 0.5223
# Epoch 67/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.1788 - mean_absolute_error: 0.4897 - val_loss: 0.1611 - val_mean_absolute_error: 0.5213
# Epoch 68/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.1756 - mean_absolute_error: 0.4859 - val_loss: 0.1602 - val_mean_absolute_error: 0.5201
# Epoch 69/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 0.1720 - mean_absolute_error: 0.4818 - val_loss: 0.1592 - val_mean_absolute_error: 0.5188
# Epoch 70/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 0.1680 - mean_absolute_error: 0.4771 - val_loss: 0.1581 - val_mean_absolute_error: 0.5173
# Epoch 71/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 0.1636 - mean_absolute_error: 0.4719 - val_loss: 0.1570 - val_mean_absolute_error: 0.5157
# Epoch 72/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.1589 - mean_absolute_error: 0.4662 - val_loss: 0.1557 - val_mean_absolute_error: 0.5139
# Epoch 73/250
# 1822/1822 [==============================] - 1s 450us/step - loss: 0.1538 - mean_absolute_error: 0.4599 - val_loss: 0.1542 - val_mean_absolute_error: 0.5119
# Epoch 74/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.1483 - mean_absolute_error: 0.4530 - val_loss: 0.1524 - val_mean_absolute_error: 0.5093
# Epoch 75/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 0.1425 - mean_absolute_error: 0.4456 - val_loss: 0.1503 - val_mean_absolute_error: 0.5062
# Epoch 76/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.1362 - mean_absolute_error: 0.4375 - val_loss: 0.1481 - val_mean_absolute_error: 0.5029
# Epoch 77/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.1295 - mean_absolute_error: 0.4284 - val_loss: 0.1453 - val_mean_absolute_error: 0.4986
# Epoch 78/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.1225 - mean_absolute_error: 0.4186 - val_loss: 0.1423 - val_mean_absolute_error: 0.4938
# Epoch 79/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.1150 - mean_absolute_error: 0.4078 - val_loss: 0.1388 - val_mean_absolute_error: 0.4882
# Epoch 80/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 0.1072 - mean_absolute_error: 0.3961 - val_loss: 0.1348 - val_mean_absolute_error: 0.4814
# Epoch 81/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0993 - mean_absolute_error: 0.3835 - val_loss: 0.1301 - val_mean_absolute_error: 0.4733
# Epoch 82/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0911 - mean_absolute_error: 0.3697 - val_loss: 0.1250 - val_mean_absolute_error: 0.4641
# Epoch 83/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0829 - mean_absolute_error: 0.3550 - val_loss: 0.1191 - val_mean_absolute_error: 0.4531
# Epoch 84/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0745 - mean_absolute_error: 0.3388 - val_loss: 0.1119 - val_mean_absolute_error: 0.4391
# Epoch 85/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 0.0663 - mean_absolute_error: 0.3215 - val_loss: 0.1041 - val_mean_absolute_error: 0.4232
# Epoch 86/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0582 - mean_absolute_error: 0.3028 - val_loss: 0.0952 - val_mean_absolute_error: 0.4040
# Epoch 87/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0504 - mean_absolute_error: 0.2830 - val_loss: 0.0857 - val_mean_absolute_error: 0.3823
# Epoch 88/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0429 - mean_absolute_error: 0.2620 - val_loss: 0.0757 - val_mean_absolute_error: 0.3577
# Epoch 89/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 0.0360 - mean_absolute_error: 0.2403 - val_loss: 0.0651 - val_mean_absolute_error: 0.3294
# Epoch 90/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0295 - mean_absolute_error: 0.2174 - val_loss: 0.0543 - val_mean_absolute_error: 0.2980
# Epoch 91/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0237 - mean_absolute_error: 0.1940 - val_loss: 0.0440 - val_mean_absolute_error: 0.2643
# Epoch 92/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 0.0186 - mean_absolute_error: 0.1702 - val_loss: 0.0345 - val_mean_absolute_error: 0.2290
# Epoch 93/250
# 1822/1822 [==============================] - 1s 453us/step - loss: 0.0143 - mean_absolute_error: 0.1469 - val_loss: 0.0261 - val_mean_absolute_error: 0.1929
# Epoch 94/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 0.0108 - mean_absolute_error: 0.1246 - val_loss: 0.0192 - val_mean_absolute_error: 0.1587
# Epoch 95/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0081 - mean_absolute_error: 0.1049 - val_loss: 0.0142 - val_mean_absolute_error: 0.1303
# Epoch 96/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0061 - mean_absolute_error: 0.0888 - val_loss: 0.0110 - val_mean_absolute_error: 0.1126
# Epoch 97/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0048 - mean_absolute_error: 0.0765 - val_loss: 0.0093 - val_mean_absolute_error: 0.1046
# Epoch 98/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0041 - mean_absolute_error: 0.0683 - val_loss: 0.0087 - val_mean_absolute_error: 0.1038
# Epoch 99/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0037 - mean_absolute_error: 0.0639 - val_loss: 0.0088 - val_mean_absolute_error: 0.1061
# Epoch 100/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0036 - mean_absolute_error: 0.0618 - val_loss: 0.0090 - val_mean_absolute_error: 0.1084
# Epoch 101/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0036 - mean_absolute_error: 0.0612 - val_loss: 0.0092 - val_mean_absolute_error: 0.1099
# Epoch 102/250
# 1822/1822 [==============================] - 1s 450us/step - loss: 0.0036 - mean_absolute_error: 0.0607 - val_loss: 0.0092 - val_mean_absolute_error: 0.1105
# Epoch 103/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0035 - mean_absolute_error: 0.0607 - val_loss: 0.0092 - val_mean_absolute_error: 0.1104
# Epoch 104/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0035 - mean_absolute_error: 0.0609 - val_loss: 0.0091 - val_mean_absolute_error: 0.1096
# Epoch 105/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0035 - mean_absolute_error: 0.0605 - val_loss: 0.0090 - val_mean_absolute_error: 0.1086
# Epoch 106/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0035 - mean_absolute_error: 0.0604 - val_loss: 0.0091 - val_mean_absolute_error: 0.1090
# Epoch 107/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0035 - mean_absolute_error: 0.0609 - val_loss: 0.0091 - val_mean_absolute_error: 0.1095
# Epoch 108/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 0.0035 - mean_absolute_error: 0.0606 - val_loss: 0.0092 - val_mean_absolute_error: 0.1098
# Epoch 109/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0035 - mean_absolute_error: 0.0598 - val_loss: 0.0092 - val_mean_absolute_error: 0.1099
# Epoch 110/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0035 - mean_absolute_error: 0.0594 - val_loss: 0.0090 - val_mean_absolute_error: 0.1083
# Epoch 111/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 0.0035 - mean_absolute_error: 0.0595 - val_loss: 0.0090 - val_mean_absolute_error: 0.1082
# Epoch 112/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0035 - mean_absolute_error: 0.0603 - val_loss: 0.0090 - val_mean_absolute_error: 0.1086
# Epoch 113/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0035 - mean_absolute_error: 0.0597 - val_loss: 0.0090 - val_mean_absolute_error: 0.1090
# Epoch 114/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0035 - mean_absolute_error: 0.0594 - val_loss: 0.0090 - val_mean_absolute_error: 0.1087
# Epoch 115/250
# 1822/1822 [==============================] - 1s 457us/step - loss: 0.0034 - mean_absolute_error: 0.0599 - val_loss: 0.0088 - val_mean_absolute_error: 0.1072
# Epoch 116/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0034 - mean_absolute_error: 0.0595 - val_loss: 0.0088 - val_mean_absolute_error: 0.1067
# Epoch 117/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 0.0034 - mean_absolute_error: 0.0589 - val_loss: 0.0092 - val_mean_absolute_error: 0.1103
# Epoch 118/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0034 - mean_absolute_error: 0.0596 - val_loss: 0.0090 - val_mean_absolute_error: 0.1088
# Epoch 119/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0034 - mean_absolute_error: 0.0585 - val_loss: 0.0087 - val_mean_absolute_error: 0.1061
# Epoch 120/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0034 - mean_absolute_error: 0.0579 - val_loss: 0.0086 - val_mean_absolute_error: 0.1049
# Epoch 121/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0033 - mean_absolute_error: 0.0586 - val_loss: 0.0090 - val_mean_absolute_error: 0.1087
# Epoch 122/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0033 - mean_absolute_error: 0.0566 - val_loss: 0.0087 - val_mean_absolute_error: 0.1065
# Epoch 123/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 0.0033 - mean_absolute_error: 0.0580 - val_loss: 0.0084 - val_mean_absolute_error: 0.1030
# Epoch 124/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0033 - mean_absolute_error: 0.0567 - val_loss: 0.0086 - val_mean_absolute_error: 0.1057
# Epoch 125/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0032 - mean_absolute_error: 0.0567 - val_loss: 0.0083 - val_mean_absolute_error: 0.1028
# Epoch 126/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0032 - mean_absolute_error: 0.0569 - val_loss: 0.0084 - val_mean_absolute_error: 0.1036
# Epoch 127/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.0031 - mean_absolute_error: 0.0552 - val_loss: 0.0083 - val_mean_absolute_error: 0.1029
# Epoch 128/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0031 - mean_absolute_error: 0.0557 - val_loss: 0.0081 - val_mean_absolute_error: 0.1016
# Epoch 129/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0031 - mean_absolute_error: 0.0559 - val_loss: 0.0082 - val_mean_absolute_error: 0.1029
# Epoch 130/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0030 - mean_absolute_error: 0.0544 - val_loss: 0.0079 - val_mean_absolute_error: 0.0996
# Epoch 131/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0030 - mean_absolute_error: 0.0542 - val_loss: 0.0080 - val_mean_absolute_error: 0.1011
# Epoch 132/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0030 - mean_absolute_error: 0.0552 - val_loss: 0.0081 - val_mean_absolute_error: 0.1016
# Epoch 133/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0029 - mean_absolute_error: 0.0526 - val_loss: 0.0077 - val_mean_absolute_error: 0.0986
# Epoch 134/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0028 - mean_absolute_error: 0.0523 - val_loss: 0.0077 - val_mean_absolute_error: 0.0986
# Epoch 135/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0027 - mean_absolute_error: 0.0514 - val_loss: 0.0075 - val_mean_absolute_error: 0.0966
# Epoch 136/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0027 - mean_absolute_error: 0.0512 - val_loss: 0.0080 - val_mean_absolute_error: 0.1013
# Epoch 137/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0028 - mean_absolute_error: 0.0524 - val_loss: 0.0079 - val_mean_absolute_error: 0.1001
# Epoch 138/250
# 1822/1822 [==============================] - 1s 448us/step - loss: 0.0027 - mean_absolute_error: 0.0508 - val_loss: 0.0071 - val_mean_absolute_error: 0.0929
# Epoch 139/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0025 - mean_absolute_error: 0.0489 - val_loss: 0.0069 - val_mean_absolute_error: 0.0922
# Epoch 140/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0024 - mean_absolute_error: 0.0483 - val_loss: 0.0073 - val_mean_absolute_error: 0.0959
# Epoch 141/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 0.0024 - mean_absolute_error: 0.0483 - val_loss: 0.0074 - val_mean_absolute_error: 0.0966
# Epoch 142/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0023 - mean_absolute_error: 0.0487 - val_loss: 0.0069 - val_mean_absolute_error: 0.0928
# Epoch 143/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0021 - mean_absolute_error: 0.0449 - val_loss: 0.0063 - val_mean_absolute_error: 0.0878
# Epoch 144/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0023 - mean_absolute_error: 0.0495 - val_loss: 0.0061 - val_mean_absolute_error: 0.0858
# Epoch 145/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0031 - mean_absolute_error: 0.0646 - val_loss: 0.0065 - val_mean_absolute_error: 0.0897
# Epoch 146/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0029 - mean_absolute_error: 0.0591 - val_loss: 0.0060 - val_mean_absolute_error: 0.0841
# Epoch 147/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0023 - mean_absolute_error: 0.0529 - val_loss: 0.0058 - val_mean_absolute_error: 0.0837
# Epoch 148/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0020 - mean_absolute_error: 0.0464 - val_loss: 0.0064 - val_mean_absolute_error: 0.0897
# Epoch 149/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 0.0022 - mean_absolute_error: 0.0509 - val_loss: 0.0066 - val_mean_absolute_error: 0.0917
# Epoch 150/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0169 - mean_absolute_error: 0.1517 - val_loss: 0.0066 - val_mean_absolute_error: 0.0888
# Epoch 151/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 0.0052 - mean_absolute_error: 0.0824 - val_loss: 0.0072 - val_mean_absolute_error: 0.0960
# Epoch 152/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0036 - mean_absolute_error: 0.0695 - val_loss: 0.0065 - val_mean_absolute_error: 0.0904
# Epoch 153/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0029 - mean_absolute_error: 0.0590 - val_loss: 0.0061 - val_mean_absolute_error: 0.0864
# Epoch 154/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0023 - mean_absolute_error: 0.0500 - val_loss: 0.0059 - val_mean_absolute_error: 0.0838
# Epoch 155/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 0.0019 - mean_absolute_error: 0.0448 - val_loss: 0.0053 - val_mean_absolute_error: 0.0803
# Epoch 156/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0019 - mean_absolute_error: 0.0454 - val_loss: 0.0052 - val_mean_absolute_error: 0.0787
# Epoch 157/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0043 - mean_absolute_error: 0.0786 - val_loss: 0.0074 - val_mean_absolute_error: 0.0990
# Epoch 158/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0209 - mean_absolute_error: 0.1728 - val_loss: 0.0086 - val_mean_absolute_error: 0.1033
# Epoch 159/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0098 - mean_absolute_error: 0.1118 - val_loss: 0.0075 - val_mean_absolute_error: 0.1000
# Epoch 160/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0158 - mean_absolute_error: 0.1397 - val_loss: 0.1158 - val_mean_absolute_error: 0.4581
# Epoch 161/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0886 - mean_absolute_error: 0.3180 - val_loss: 0.0803 - val_mean_absolute_error: 0.3310
# Epoch 162/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 30.0101 - mean_absolute_error: 30.4771 - val_loss: 134.5435 - val_mean_absolute_error: 135.0435
# Epoch 163/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 67.6919 - mean_absolute_error: 68.1667 - val_loss: 35.1086 - val_mean_absolute_error: 35.6086
# Epoch 164/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 105.5243 - mean_absolute_error: 106.0243 - val_loss: 167.2821 - val_mean_absolute_error: 167.7821
# Epoch 165/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 179.5267 - mean_absolute_error: 180.0267 - val_loss: 135.5888 - val_mean_absolute_error: 136.0888
# Epoch 166/250
# 1822/1822 [==============================] - 1s 448us/step - loss: 214.9492 - mean_absolute_error: 215.4492 - val_loss: 10.8507 - val_mean_absolute_error: 11.3507
# Epoch 167/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 299.2290 - mean_absolute_error: 299.7290 - val_loss: 342.1162 - val_mean_absolute_error: 342.6162
# Epoch 168/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 158.4223 - mean_absolute_error: 158.9223 - val_loss: 161.2426 - val_mean_absolute_error: 161.7426
# Epoch 169/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 161.0745 - mean_absolute_error: 161.5745 - val_loss: 62.1468 - val_mean_absolute_error: 62.6468
# Epoch 170/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 165.4397 - mean_absolute_error: 165.9397 - val_loss: 262.0503 - val_mean_absolute_error: 262.5504
# Epoch 171/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 200.6706 - mean_absolute_error: 201.1706 - val_loss: 251.7533 - val_mean_absolute_error: 252.2533
# Epoch 172/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 235.7188 - mean_absolute_error: 236.2188 - val_loss: 26.7071 - val_mean_absolute_error: 27.2071
# Epoch 173/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 220.8333 - mean_absolute_error: 221.3333 - val_loss: 468.2658 - val_mean_absolute_error: 468.7658
# Epoch 174/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 300.0138 - mean_absolute_error: 300.5138 - val_loss: 242.1502 - val_mean_absolute_error: 242.6502
# Epoch 175/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 315.6062 - mean_absolute_error: 316.1062 - val_loss: 81.5218 - val_mean_absolute_error: 82.0218
# Epoch 176/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 155.1756 - mean_absolute_error: 155.6756 - val_loss: 334.0794 - val_mean_absolute_error: 334.5794
# Epoch 177/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 371.7527 - mean_absolute_error: 372.2527 - val_loss: 549.7889 - val_mean_absolute_error: 550.2889
# Epoch 178/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 448.0600 - mean_absolute_error: 448.5599 - val_loss: 534.1972 - val_mean_absolute_error: 534.6972
# Epoch 179/250
# 1822/1822 [==============================] - 1s 454us/step - loss: 524.8541 - mean_absolute_error: 525.3542 - val_loss: 1.3184 - val_mean_absolute_error: 1.8184
# Epoch 180/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 485.6464 - mean_absolute_error: 486.1464 - val_loss: 1120.5374 - val_mean_absolute_error: 1121.0374
# Epoch 181/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 683.9541 - mean_absolute_error: 684.4541 - val_loss: 465.7388 - val_mean_absolute_error: 466.2388
# Epoch 182/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 716.3882 - mean_absolute_error: 716.8773 - val_loss: 2174.1660 - val_mean_absolute_error: 2174.6658
# Epoch 183/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 1340.0437 - mean_absolute_error: 1340.5438 - val_loss: 1846.4805 - val_mean_absolute_error: 1846.9804
# Epoch 184/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 1638.6228 - mean_absolute_error: 1639.1228 - val_loss: 1260.7139 - val_mean_absolute_error: 1261.2139
# Epoch 185/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 608.3683 - mean_absolute_error: 608.8683 - val_loss: 835.6714 - val_mean_absolute_error: 836.1714
# Epoch 186/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 620.3200 - mean_absolute_error: 620.8200 - val_loss: 991.7474 - val_mean_absolute_error: 992.2474
# Epoch 187/250
# 1822/1822 [==============================] - 1s 454us/step - loss: 687.5484 - mean_absolute_error: 688.0484 - val_loss: 1056.2367 - val_mean_absolute_error: 1056.7367
# Epoch 188/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 787.5479 - mean_absolute_error: 788.0479 - val_loss: 1410.1249 - val_mean_absolute_error: 1410.6249
# Epoch 189/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 952.2332 - mean_absolute_error: 952.7332 - val_loss: 607.0870 - val_mean_absolute_error: 607.5870
# Epoch 190/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 1818.9785 - mean_absolute_error: 1819.4785 - val_loss: 1164.2966 - val_mean_absolute_error: 1164.7966
# Epoch 191/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 3140.6291 - mean_absolute_error: 3141.1292 - val_loss: 1022.2813 - val_mean_absolute_error: 1022.7813
# Epoch 192/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 3572.9929 - mean_absolute_error: 3573.4930 - val_loss: 2498.9362 - val_mean_absolute_error: 2499.4362
# Epoch 193/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 3847.3199 - mean_absolute_error: 3847.8198 - val_loss: 4860.0191 - val_mean_absolute_error: 4860.5191
# Epoch 194/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 2211.0790 - mean_absolute_error: 2211.5791 - val_loss: 6349.6472 - val_mean_absolute_error: 6350.1472
# Epoch 195/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 2202.0639 - mean_absolute_error: 2202.5639 - val_loss: 3951.0081 - val_mean_absolute_error: 3951.5082
# Epoch 196/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 4460.6998 - mean_absolute_error: 4461.1997 - val_loss: 10446.6502 - val_mean_absolute_error: 10447.1502
# Epoch 197/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 6084.0757 - mean_absolute_error: 6084.5759 - val_loss: 11256.3690 - val_mean_absolute_error: 11256.8685
# Epoch 198/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 7669.7551 - mean_absolute_error: 7670.2550 - val_loss: 9376.1047 - val_mean_absolute_error: 9376.6053
# Epoch 199/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 9347.4181 - mean_absolute_error: 9347.9183 - val_loss: 6065.9381 - val_mean_absolute_error: 6066.4378
# Epoch 200/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 3261.4183 - mean_absolute_error: 3261.9182 - val_loss: 5734.4828 - val_mean_absolute_error: 5734.9828
# Epoch 201/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 3654.2582 - mean_absolute_error: 3654.7581 - val_loss: 2542.7821 - val_mean_absolute_error: 2543.2821
# Epoch 202/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 7148.9961 - mean_absolute_error: 7149.4959 - val_loss: 2792.0450 - val_mean_absolute_error: 2792.5451
# Epoch 203/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 12725.9649 - mean_absolute_error: 12726.4648 - val_loss: 1379.0720 - val_mean_absolute_error: 1379.5720
# Epoch 204/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 14556.4420 - mean_absolute_error: 14556.9419 - val_loss: 6892.8766 - val_mean_absolute_error: 6893.3766
# Epoch 205/250
# 1822/1822 [==============================] - 1s 450us/step - loss: 15695.4287 - mean_absolute_error: 15695.9298 - val_loss: 16135.4379 - val_mean_absolute_error: 16135.9373
# Epoch 206/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 8565.9691 - mean_absolute_error: 8566.4692 - val_loss: 7755.7678 - val_mean_absolute_error: 7756.2683
# Epoch 207/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 12604.6393 - mean_absolute_error: 12605.1394 - val_loss: 2466.9928 - val_mean_absolute_error: 2467.4928
# Epoch 208/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 7207.1091 - mean_absolute_error: 7207.6089 - val_loss: 34799.6406 - val_mean_absolute_error: 34800.1423
# Epoch 209/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 32939.6885 - mean_absolute_error: 32940.1885 - val_loss: 42936.5112 - val_mean_absolute_error: 42937.0112
# Epoch 210/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 47458.4027 - mean_absolute_error: 47458.9036 - val_loss: 48511.9145 - val_mean_absolute_error: 48512.4145
# Epoch 211/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 38916.6987 - mean_absolute_error: 38917.1980 - val_loss: 76628.6550 - val_mean_absolute_error: 76629.1550
# Epoch 212/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 61735.3537 - mean_absolute_error: 61735.8530 - val_loss: 23691.4576 - val_mean_absolute_error: 23691.9566
# Epoch 213/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 38068.8631 - mean_absolute_error: 38069.3631 - val_loss: 19943.0845 - val_mean_absolute_error: 19943.5834
# Epoch 214/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 17554.1841 - mean_absolute_error: 17554.6842 - val_loss: 69165.8494 - val_mean_absolute_error: 69166.3494
# Epoch 215/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 63847.3759 - mean_absolute_error: 63847.8759 - val_loss: 26596.6019 - val_mean_absolute_error: 26597.1011
# Epoch 216/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 36171.3512 - mean_absolute_error: 36171.8500 - val_loss: 3905.2775 - val_mean_absolute_error: 3905.7776
# Epoch 217/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 19222.5019 - mean_absolute_error: 19223.0024 - val_loss: 100401.4197 - val_mean_absolute_error: 100401.9241
# Epoch 218/250
# 1822/1822 [==============================] - 1s 453us/step - loss: 92570.9347 - mean_absolute_error: 92571.4316 - val_loss: 123021.4153 - val_mean_absolute_error: 123021.9153
# Epoch 219/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 134571.1809 - mean_absolute_error: 134571.6792 - val_loss: 134851.7654 - val_mean_absolute_error: 134852.2654
# Epoch 220/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 110419.9133 - mean_absolute_error: 110420.4128 - val_loss: 214153.5291 - val_mean_absolute_error: 214154.0291
# Epoch 221/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 173765.2206 - mean_absolute_error: 173765.7184 - val_loss: 68563.6931 - val_mean_absolute_error: 68564.1931
# Epoch 222/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 107071.3857 - mean_absolute_error: 107071.8857 - val_loss: 54427.8945 - val_mean_absolute_error: 54428.3923
# Epoch 223/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 48755.6170 - mean_absolute_error: 48756.1167 - val_loss: 196712.3753 - val_mean_absolute_error: 196712.8840
# Epoch 224/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 179727.7249 - mean_absolute_error: 179728.2293 - val_loss: 76734.0828 - val_mean_absolute_error: 76734.5794
# Epoch 225/250
# 1822/1822 [==============================] - 1s 453us/step - loss: 102223.7668 - mean_absolute_error: 102224.2663 - val_loss: 9234.6121 - val_mean_absolute_error: 9235.1121
# Epoch 226/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 53459.8608 - mean_absolute_error: 53460.3601 - val_loss: 284742.8909 - val_mean_absolute_error: 284743.4084
# Epoch 227/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 260623.2817 - mean_absolute_error: 260623.7883 - val_loss: 348494.3909 - val_mean_absolute_error: 348494.8947
# Epoch 228/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 379991.2721 - mean_absolute_error: 379991.7638 - val_loss: 378293.0291 - val_mean_absolute_error: 378293.5291
# Epoch 229/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 311923.6077 - mean_absolute_error: 311924.1061 - val_loss: 601795.5779 - val_mean_absolute_error: 601796.0779
# Epoch 230/250
# 1822/1822 [==============================] - 1s 454us/step - loss: 489518.2242 - mean_absolute_error: 489518.7132 - val_loss: 195011.6047 - val_mean_absolute_error: 195012.1116
# Epoch 231/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 301549.4704 - mean_absolute_error: 301549.9715 - val_loss: 151627.2791 - val_mean_absolute_error: 151627.7791
# Epoch 232/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 136695.6988 - mean_absolute_error: 136696.2032 - val_loss: 556183.9923 - val_mean_absolute_error: 556184.5197
# Epoch 233/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 506322.7923 - mean_absolute_error: 506323.3187 - val_loss: 218039.1409 - val_mean_absolute_error: 218039.6584
# Epoch 234/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 288384.6290 - mean_absolute_error: 288385.1329 - val_loss: 24255.1526 - val_mean_absolute_error: 24255.6526
# Epoch 235/250
# 1822/1822 [==============================] - 1s 448us/step - loss: 149953.8128 - mean_absolute_error: 149954.3062 - val_loss: 804288.1996 - val_mean_absolute_error: 804288.8322
# Epoch 236/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 734258.9072 - mean_absolute_error: 734259.3732 - val_loss: 983965.0822 - val_mean_absolute_error: 983965.6096
# Epoch 237/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 1071679.4520 - mean_absolute_error: 1071679.9256 - val_loss: 1064401.3904 - val_mean_absolute_error: 1064401.8904
# Epoch 238/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 879839.4476 - mean_absolute_error: 879839.9454 - val_loss: 1694316.8355 - val_mean_absolute_error: 1694317.1952
# Epoch 239/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 1379430.8692 - mean_absolute_error: 1379431.2838 - val_loss: 551392.9923 - val_mean_absolute_error: 551393.5197
# Epoch 240/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 849662.8934 - mean_absolute_error: 849663.3500 - val_loss: 425570.1990 - val_mean_absolute_error: 425570.7029
# Epoch 241/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 384543.4951 - mean_absolute_error: 384543.9839 - val_loss: 1569314.9298 - val_mean_absolute_error: 1569315.2895
# Epoch 242/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 1426792.8696 - mean_absolute_error: 1426793.3015 - val_loss: 616292.1096 - val_mean_absolute_error: 616292.6096
# Epoch 243/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 813057.3838 - mean_absolute_error: 813057.8773 - val_loss: 66588.8459 - val_mean_absolute_error: 66589.3425
# Epoch 244/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 421910.8930 - mean_absolute_error: 421911.4038 - val_loss: 2268565.0000 - val_mean_absolute_error: 2268565.7500
# Epoch 245/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 2069146.1010 - mean_absolute_error: 2069146.5527 - val_loss: 2774962.2500 - val_mean_absolute_error: 2774963.1096
# Epoch 246/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 3021121.1320 - mean_absolute_error: 3021121.5091 - val_loss: 2998121.5307 - val_mean_absolute_error: 2998122.0000
# Epoch 247/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 2480440.5864 - mean_absolute_error: 2480441.2445 - val_loss: 4773466.8421 - val_mean_absolute_error: 4773468.0000
# Epoch 248/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 3887546.1144 - mean_absolute_error: 3887546.7854 - val_loss: 1555803.1645 - val_mean_absolute_error: 1555803.7346
# Epoch 249/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 2394457.2099 - mean_absolute_error: 2394457.9055 - val_loss: 1197656.8904 - val_mean_absolute_error: 1197657.3904
# Epoch 250/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 1083078.0154 - mean_absolute_error: 1083078.5329 - val_loss: 4424694.2193 - val_mean_absolute_error: 4424695.5000

# %% [markdown]
# Let's plot the loss for the testing data versus the learning rate.  We can see that it explodes past a learning rate of 1, so let's focus our window to before this point.

# %%
plt.semilogx(history.history['lr'], history.history['val_loss'])
plt.legend(['Learning Rate', 'Validation Loss'])

# %%
plt.semilogx(history.history['lr'][:140], history.history['loss'][:140])

# %% [markdown]
# It looks like the learning rate of 0.1 seems to work the best.  Let's use that learning rate and train the network this time for real.  Once we train the network, let's predict the prices for the training and test data.

# %%
# Observing the above graph, 0.1 seems to be the best learning rate
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])


optimizer = SGD(lr=0.1, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, validation_data=(X_test_reshape, y_test_reshape))
# Out:
# Train on 1822 samples, validate on 456 samples
# Epoch 1/250
# 1822/1822 [==============================] - 2s 1ms/step - loss: 0.0707 - mean_absolute_error: 0.3086 - val_loss: 0.0498 - val_mean_absolute_error: 0.2903
# Epoch 2/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0201 - mean_absolute_error: 0.1673 - val_loss: 0.0157 - val_mean_absolute_error: 0.1421
# Epoch 3/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0095 - mean_absolute_error: 0.1077 - val_loss: 0.0135 - val_mean_absolute_error: 0.1371
# Epoch 4/250
# 1822/1822 [==============================] - 1s 453us/step - loss: 0.0064 - mean_absolute_error: 0.0888 - val_loss: 0.0085 - val_mean_absolute_error: 0.1055
# Epoch 5/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 0.0045 - mean_absolute_error: 0.0713 - val_loss: 0.0087 - val_mean_absolute_error: 0.1021
# Epoch 6/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 0.0034 - mean_absolute_error: 0.0586 - val_loss: 0.0074 - val_mean_absolute_error: 0.0951
# Epoch 7/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0030 - mean_absolute_error: 0.0545 - val_loss: 0.0074 - val_mean_absolute_error: 0.0971
# Epoch 8/250
# 1822/1822 [==============================] - 1s 463us/step - loss: 0.0025 - mean_absolute_error: 0.0491 - val_loss: 0.0069 - val_mean_absolute_error: 0.0928
# Epoch 9/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 0.0023 - mean_absolute_error: 0.0472 - val_loss: 0.0069 - val_mean_absolute_error: 0.0908
# Epoch 10/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0021 - mean_absolute_error: 0.0469 - val_loss: 0.0067 - val_mean_absolute_error: 0.0904
# Epoch 11/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 0.0020 - mean_absolute_error: 0.0441 - val_loss: 0.0077 - val_mean_absolute_error: 0.0984
# Epoch 12/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0021 - mean_absolute_error: 0.0463 - val_loss: 0.0069 - val_mean_absolute_error: 0.0914
# Epoch 13/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0019 - mean_absolute_error: 0.0433 - val_loss: 0.0066 - val_mean_absolute_error: 0.0884
# Epoch 14/250
# 1822/1822 [==============================] - 1s 452us/step - loss: 0.0018 - mean_absolute_error: 0.0415 - val_loss: 0.0067 - val_mean_absolute_error: 0.0888
# Epoch 15/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0018 - mean_absolute_error: 0.0414 - val_loss: 0.0066 - val_mean_absolute_error: 0.0885
# Epoch 16/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0018 - mean_absolute_error: 0.0424 - val_loss: 0.0068 - val_mean_absolute_error: 0.0902
# Epoch 17/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0018 - mean_absolute_error: 0.0410 - val_loss: 0.0065 - val_mean_absolute_error: 0.0877
# Epoch 18/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0017 - mean_absolute_error: 0.0411 - val_loss: 0.0065 - val_mean_absolute_error: 0.0877
# Epoch 19/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0017 - mean_absolute_error: 0.0407 - val_loss: 0.0066 - val_mean_absolute_error: 0.0880
# Epoch 20/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0018 - mean_absolute_error: 0.0423 - val_loss: 0.0064 - val_mean_absolute_error: 0.0869
# Epoch 21/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0018 - mean_absolute_error: 0.0429 - val_loss: 0.0066 - val_mean_absolute_error: 0.0891
# Epoch 22/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 0.0017 - mean_absolute_error: 0.0400 - val_loss: 0.0065 - val_mean_absolute_error: 0.0891
# Epoch 23/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0017 - mean_absolute_error: 0.0396 - val_loss: 0.0062 - val_mean_absolute_error: 0.0861
# Epoch 24/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0017 - mean_absolute_error: 0.0395 - val_loss: 0.0062 - val_mean_absolute_error: 0.0857
# Epoch 25/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0016 - mean_absolute_error: 0.0398 - val_loss: 0.0067 - val_mean_absolute_error: 0.0911
# Epoch 26/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0017 - mean_absolute_error: 0.0402 - val_loss: 0.0070 - val_mean_absolute_error: 0.0928
# Epoch 27/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0018 - mean_absolute_error: 0.0410 - val_loss: 0.0061 - val_mean_absolute_error: 0.0847
# Epoch 28/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0016 - mean_absolute_error: 0.0397 - val_loss: 0.0061 - val_mean_absolute_error: 0.0848
# Epoch 29/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0016 - mean_absolute_error: 0.0389 - val_loss: 0.0061 - val_mean_absolute_error: 0.0846
# Epoch 30/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0016 - mean_absolute_error: 0.0391 - val_loss: 0.0060 - val_mean_absolute_error: 0.0842
# Epoch 31/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0016 - mean_absolute_error: 0.0384 - val_loss: 0.0059 - val_mean_absolute_error: 0.0837
# Epoch 32/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0017 - mean_absolute_error: 0.0411 - val_loss: 0.0059 - val_mean_absolute_error: 0.0842
# Epoch 33/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0017 - mean_absolute_error: 0.0394 - val_loss: 0.0058 - val_mean_absolute_error: 0.0840
# Epoch 34/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0016 - mean_absolute_error: 0.0386 - val_loss: 0.0059 - val_mean_absolute_error: 0.0842
# Epoch 35/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0015 - mean_absolute_error: 0.0380 - val_loss: 0.0057 - val_mean_absolute_error: 0.0828
# Epoch 36/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.0015 - mean_absolute_error: 0.0383 - val_loss: 0.0061 - val_mean_absolute_error: 0.0842
# Epoch 37/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0017 - mean_absolute_error: 0.0396 - val_loss: 0.0058 - val_mean_absolute_error: 0.0836
# Epoch 38/250
# 1822/1822 [==============================] - 1s 448us/step - loss: 0.0015 - mean_absolute_error: 0.0375 - val_loss: 0.0056 - val_mean_absolute_error: 0.0827
# Epoch 39/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 0.0015 - mean_absolute_error: 0.0378 - val_loss: 0.0055 - val_mean_absolute_error: 0.0816
# Epoch 40/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 0.0015 - mean_absolute_error: 0.0377 - val_loss: 0.0056 - val_mean_absolute_error: 0.0813
# Epoch 41/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0015 - mean_absolute_error: 0.0369 - val_loss: 0.0055 - val_mean_absolute_error: 0.0813
# Epoch 42/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0015 - mean_absolute_error: 0.0367 - val_loss: 0.0054 - val_mean_absolute_error: 0.0804
# Epoch 43/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0015 - mean_absolute_error: 0.0379 - val_loss: 0.0054 - val_mean_absolute_error: 0.0804
# Epoch 44/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0014 - mean_absolute_error: 0.0366 - val_loss: 0.0054 - val_mean_absolute_error: 0.0800
# Epoch 45/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0014 - mean_absolute_error: 0.0361 - val_loss: 0.0054 - val_mean_absolute_error: 0.0803
# Epoch 46/250
# 1822/1822 [==============================] - 1s 455us/step - loss: 0.0014 - mean_absolute_error: 0.0360 - val_loss: 0.0053 - val_mean_absolute_error: 0.0798
# Epoch 47/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0014 - mean_absolute_error: 0.0373 - val_loss: 0.0053 - val_mean_absolute_error: 0.0796
# Epoch 48/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0014 - mean_absolute_error: 0.0365 - val_loss: 0.0054 - val_mean_absolute_error: 0.0793
# Epoch 49/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0014 - mean_absolute_error: 0.0368 - val_loss: 0.0052 - val_mean_absolute_error: 0.0793
# Epoch 50/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0014 - mean_absolute_error: 0.0388 - val_loss: 0.0053 - val_mean_absolute_error: 0.0801
# Epoch 51/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0014 - mean_absolute_error: 0.0366 - val_loss: 0.0055 - val_mean_absolute_error: 0.0797
# Epoch 52/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0015 - mean_absolute_error: 0.0400 - val_loss: 0.0052 - val_mean_absolute_error: 0.0784
# Epoch 53/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0014 - mean_absolute_error: 0.0367 - val_loss: 0.0050 - val_mean_absolute_error: 0.0774
# Epoch 54/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0013 - mean_absolute_error: 0.0350 - val_loss: 0.0050 - val_mean_absolute_error: 0.0777
# Epoch 55/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0013 - mean_absolute_error: 0.0349 - val_loss: 0.0050 - val_mean_absolute_error: 0.0773
# Epoch 56/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0013 - mean_absolute_error: 0.0354 - val_loss: 0.0050 - val_mean_absolute_error: 0.0771
# Epoch 57/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0013 - mean_absolute_error: 0.0343 - val_loss: 0.0049 - val_mean_absolute_error: 0.0767
# Epoch 58/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0013 - mean_absolute_error: 0.0345 - val_loss: 0.0049 - val_mean_absolute_error: 0.0767
# Epoch 59/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 0.0013 - mean_absolute_error: 0.0355 - val_loss: 0.0050 - val_mean_absolute_error: 0.0764
# Epoch 60/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0015 - mean_absolute_error: 0.0384 - val_loss: 0.0048 - val_mean_absolute_error: 0.0756
# Epoch 61/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0014 - mean_absolute_error: 0.0374 - val_loss: 0.0048 - val_mean_absolute_error: 0.0751
# Epoch 62/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0013 - mean_absolute_error: 0.0362 - val_loss: 0.0047 - val_mean_absolute_error: 0.0749
# Epoch 63/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0013 - mean_absolute_error: 0.0355 - val_loss: 0.0048 - val_mean_absolute_error: 0.0757
# Epoch 64/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0013 - mean_absolute_error: 0.0342 - val_loss: 0.0047 - val_mean_absolute_error: 0.0746
# Epoch 65/250
# 1822/1822 [==============================] - 1s 462us/step - loss: 0.0013 - mean_absolute_error: 0.0356 - val_loss: 0.0049 - val_mean_absolute_error: 0.0757
# Epoch 66/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 0.0013 - mean_absolute_error: 0.0347 - val_loss: 0.0046 - val_mean_absolute_error: 0.0742
# Epoch 67/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0012 - mean_absolute_error: 0.0340 - val_loss: 0.0046 - val_mean_absolute_error: 0.0740
# Epoch 68/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0012 - mean_absolute_error: 0.0338 - val_loss: 0.0046 - val_mean_absolute_error: 0.0740
# Epoch 69/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0012 - mean_absolute_error: 0.0338 - val_loss: 0.0048 - val_mean_absolute_error: 0.0754
# Epoch 70/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0013 - mean_absolute_error: 0.0346 - val_loss: 0.0047 - val_mean_absolute_error: 0.0751
# Epoch 71/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 0.0013 - mean_absolute_error: 0.0338 - val_loss: 0.0045 - val_mean_absolute_error: 0.0727
# Epoch 72/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0012 - mean_absolute_error: 0.0328 - val_loss: 0.0046 - val_mean_absolute_error: 0.0732
# Epoch 73/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 0.0012 - mean_absolute_error: 0.0328 - val_loss: 0.0046 - val_mean_absolute_error: 0.0732
# Epoch 74/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0012 - mean_absolute_error: 0.0323 - val_loss: 0.0044 - val_mean_absolute_error: 0.0716
# Epoch 75/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0012 - mean_absolute_error: 0.0337 - val_loss: 0.0044 - val_mean_absolute_error: 0.0717
# Epoch 76/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 0.0012 - mean_absolute_error: 0.0363 - val_loss: 0.0043 - val_mean_absolute_error: 0.0709
# Epoch 77/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.0012 - mean_absolute_error: 0.0350 - val_loss: 0.0047 - val_mean_absolute_error: 0.0745
# Epoch 78/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0012 - mean_absolute_error: 0.0346 - val_loss: 0.0043 - val_mean_absolute_error: 0.0707
# Epoch 79/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0011 - mean_absolute_error: 0.0320 - val_loss: 0.0043 - val_mean_absolute_error: 0.0705
# Epoch 80/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.0012 - mean_absolute_error: 0.0329 - val_loss: 0.0043 - val_mean_absolute_error: 0.0709
# Epoch 81/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0011 - mean_absolute_error: 0.0325 - val_loss: 0.0043 - val_mean_absolute_error: 0.0714
# Epoch 82/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0012 - mean_absolute_error: 0.0334 - val_loss: 0.0046 - val_mean_absolute_error: 0.0737
# Epoch 83/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0012 - mean_absolute_error: 0.0327 - val_loss: 0.0048 - val_mean_absolute_error: 0.0749
# Epoch 84/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 0.0011 - mean_absolute_error: 0.0323 - val_loss: 0.0046 - val_mean_absolute_error: 0.0735
# Epoch 85/250
# 1822/1822 [==============================] - 1s 452us/step - loss: 0.0012 - mean_absolute_error: 0.0330 - val_loss: 0.0054 - val_mean_absolute_error: 0.0801
# Epoch 86/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0012 - mean_absolute_error: 0.0326 - val_loss: 0.0041 - val_mean_absolute_error: 0.0686
# Epoch 87/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.0011 - mean_absolute_error: 0.0325 - val_loss: 0.0042 - val_mean_absolute_error: 0.0702
# Epoch 88/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0012 - mean_absolute_error: 0.0346 - val_loss: 0.0040 - val_mean_absolute_error: 0.0685
# Epoch 89/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0012 - mean_absolute_error: 0.0344 - val_loss: 0.0040 - val_mean_absolute_error: 0.0685
# Epoch 90/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 0.0012 - mean_absolute_error: 0.0330 - val_loss: 0.0043 - val_mean_absolute_error: 0.0709
# Epoch 91/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0012 - mean_absolute_error: 0.0331 - val_loss: 0.0040 - val_mean_absolute_error: 0.0679
# Epoch 92/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 0.0011 - mean_absolute_error: 0.0334 - val_loss: 0.0041 - val_mean_absolute_error: 0.0687
# Epoch 93/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0011 - mean_absolute_error: 0.0338 - val_loss: 0.0039 - val_mean_absolute_error: 0.0674
# Epoch 94/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0011 - mean_absolute_error: 0.0334 - val_loss: 0.0043 - val_mean_absolute_error: 0.0706
# Epoch 95/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0012 - mean_absolute_error: 0.0327 - val_loss: 0.0041 - val_mean_absolute_error: 0.0684
# Epoch 96/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 0.0012 - mean_absolute_error: 0.0330 - val_loss: 0.0042 - val_mean_absolute_error: 0.0695
# Epoch 97/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0012 - mean_absolute_error: 0.0347 - val_loss: 0.0051 - val_mean_absolute_error: 0.0777
# Epoch 98/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0013 - mean_absolute_error: 0.0351 - val_loss: 0.0047 - val_mean_absolute_error: 0.0745
# Epoch 99/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0013 - mean_absolute_error: 0.0344 - val_loss: 0.0063 - val_mean_absolute_error: 0.0884
# Epoch 100/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0013 - mean_absolute_error: 0.0347 - val_loss: 0.0044 - val_mean_absolute_error: 0.0719
# Epoch 101/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 0.0011 - mean_absolute_error: 0.0332 - val_loss: 0.0047 - val_mean_absolute_error: 0.0745
# Epoch 102/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0011 - mean_absolute_error: 0.0332 - val_loss: 0.0040 - val_mean_absolute_error: 0.0673
# Epoch 103/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0011 - mean_absolute_error: 0.0319 - val_loss: 0.0042 - val_mean_absolute_error: 0.0693
# Epoch 104/250
# 1822/1822 [==============================] - 1s 455us/step - loss: 0.0011 - mean_absolute_error: 0.0333 - val_loss: 0.0038 - val_mean_absolute_error: 0.0662
# Epoch 105/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0010 - mean_absolute_error: 0.0306 - val_loss: 0.0037 - val_mean_absolute_error: 0.0653
# Epoch 106/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0010 - mean_absolute_error: 0.0303 - val_loss: 0.0037 - val_mean_absolute_error: 0.0651
# Epoch 107/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 0.0010 - mean_absolute_error: 0.0310 - val_loss: 0.0041 - val_mean_absolute_error: 0.0683
# Epoch 108/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 0.0012 - mean_absolute_error: 0.0351 - val_loss: 0.0037 - val_mean_absolute_error: 0.0652
# Epoch 109/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0010 - mean_absolute_error: 0.0309 - val_loss: 0.0037 - val_mean_absolute_error: 0.0649
# Epoch 110/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 0.0010 - mean_absolute_error: 0.0311 - val_loss: 0.0037 - val_mean_absolute_error: 0.0650
# Epoch 111/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 0.0010 - mean_absolute_error: 0.0303 - val_loss: 0.0037 - val_mean_absolute_error: 0.0657
# Epoch 112/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0010 - mean_absolute_error: 0.0308 - val_loss: 0.0038 - val_mean_absolute_error: 0.0669
# Epoch 113/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0011 - mean_absolute_error: 0.0315 - val_loss: 0.0037 - val_mean_absolute_error: 0.0652
# Epoch 114/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0010 - mean_absolute_error: 0.0311 - val_loss: 0.0035 - val_mean_absolute_error: 0.0640
# Epoch 115/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0010 - mean_absolute_error: 0.0304 - val_loss: 0.0037 - val_mean_absolute_error: 0.0658
# Epoch 116/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 0.0010 - mean_absolute_error: 0.0312 - val_loss: 0.0035 - val_mean_absolute_error: 0.0636
# Epoch 117/250
# 1822/1822 [==============================] - 1s 455us/step - loss: 9.8823e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0036 - val_mean_absolute_error: 0.0640
# Epoch 118/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0010 - mean_absolute_error: 0.0324 - val_loss: 0.0036 - val_mean_absolute_error: 0.0639
# Epoch 119/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 9.8297e-04 - mean_absolute_error: 0.0303 - val_loss: 0.0039 - val_mean_absolute_error: 0.0668
# Epoch 120/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0010 - mean_absolute_error: 0.0301 - val_loss: 0.0040 - val_mean_absolute_error: 0.0676
# Epoch 121/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 0.0011 - mean_absolute_error: 0.0330 - val_loss: 0.0038 - val_mean_absolute_error: 0.0656
# Epoch 122/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0011 - mean_absolute_error: 0.0328 - val_loss: 0.0036 - val_mean_absolute_error: 0.0637
# Epoch 123/250
# 1822/1822 [==============================] - 1s 457us/step - loss: 9.8710e-04 - mean_absolute_error: 0.0305 - val_loss: 0.0036 - val_mean_absolute_error: 0.0638
# Epoch 124/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 9.4978e-04 - mean_absolute_error: 0.0291 - val_loss: 0.0040 - val_mean_absolute_error: 0.0671
# Epoch 125/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0010 - mean_absolute_error: 0.0317 - val_loss: 0.0035 - val_mean_absolute_error: 0.0629
# Epoch 126/250
# 1822/1822 [==============================] - 1s 466us/step - loss: 9.5457e-04 - mean_absolute_error: 0.0295 - val_loss: 0.0034 - val_mean_absolute_error: 0.0624
# Epoch 127/250
# 1822/1822 [==============================] - 1s 457us/step - loss: 9.3659e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0034 - val_mean_absolute_error: 0.0622
# Epoch 128/250
# 1822/1822 [==============================] - 1s 448us/step - loss: 9.6054e-04 - mean_absolute_error: 0.0292 - val_loss: 0.0039 - val_mean_absolute_error: 0.0667
# Epoch 129/250
# 1822/1822 [==============================] - 1s 460us/step - loss: 0.0010 - mean_absolute_error: 0.0304 - val_loss: 0.0052 - val_mean_absolute_error: 0.0803
# Epoch 130/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 0.0012 - mean_absolute_error: 0.0328 - val_loss: 0.0047 - val_mean_absolute_error: 0.0747
# Epoch 131/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0011 - mean_absolute_error: 0.0314 - val_loss: 0.0036 - val_mean_absolute_error: 0.0632
# Epoch 132/250
# 1822/1822 [==============================] - 1s 448us/step - loss: 9.6969e-04 - mean_absolute_error: 0.0291 - val_loss: 0.0037 - val_mean_absolute_error: 0.0650
# Epoch 133/250
# 1822/1822 [==============================] - 1s 455us/step - loss: 9.5750e-04 - mean_absolute_error: 0.0290 - val_loss: 0.0033 - val_mean_absolute_error: 0.0615
# Epoch 134/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 9.4510e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0033 - val_mean_absolute_error: 0.0618
# Epoch 135/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 9.2853e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0033 - val_mean_absolute_error: 0.0614
# Epoch 136/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 9.2717e-04 - mean_absolute_error: 0.0288 - val_loss: 0.0033 - val_mean_absolute_error: 0.0612
# Epoch 137/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 9.2006e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0035 - val_mean_absolute_error: 0.0629
# Epoch 138/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 9.4069e-04 - mean_absolute_error: 0.0295 - val_loss: 0.0033 - val_mean_absolute_error: 0.0613
# Epoch 139/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 9.1601e-04 - mean_absolute_error: 0.0288 - val_loss: 0.0034 - val_mean_absolute_error: 0.0614
# Epoch 140/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 9.2398e-04 - mean_absolute_error: 0.0286 - val_loss: 0.0033 - val_mean_absolute_error: 0.0610
# Epoch 141/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 9.2188e-04 - mean_absolute_error: 0.0287 - val_loss: 0.0034 - val_mean_absolute_error: 0.0614
# Epoch 142/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 9.4041e-04 - mean_absolute_error: 0.0297 - val_loss: 0.0038 - val_mean_absolute_error: 0.0660
# Epoch 143/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 0.0010 - mean_absolute_error: 0.0306 - val_loss: 0.0049 - val_mean_absolute_error: 0.0765
# Epoch 144/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 0.0012 - mean_absolute_error: 0.0348 - val_loss: 0.0049 - val_mean_absolute_error: 0.0771
# Epoch 145/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 0.0011 - mean_absolute_error: 0.0344 - val_loss: 0.0033 - val_mean_absolute_error: 0.0609
# Epoch 146/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 9.5060e-04 - mean_absolute_error: 0.0300 - val_loss: 0.0032 - val_mean_absolute_error: 0.0603
# Epoch 147/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 9.0904e-04 - mean_absolute_error: 0.0291 - val_loss: 0.0032 - val_mean_absolute_error: 0.0606
# Epoch 148/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 9.1050e-04 - mean_absolute_error: 0.0286 - val_loss: 0.0033 - val_mean_absolute_error: 0.0608
# Epoch 149/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 9.2953e-04 - mean_absolute_error: 0.0293 - val_loss: 0.0033 - val_mean_absolute_error: 0.0611
# Epoch 150/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 8.9379e-04 - mean_absolute_error: 0.0284 - val_loss: 0.0031 - val_mean_absolute_error: 0.0601
# Epoch 151/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 8.8872e-04 - mean_absolute_error: 0.0281 - val_loss: 0.0032 - val_mean_absolute_error: 0.0598
# Epoch 152/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 8.7826e-04 - mean_absolute_error: 0.0275 - val_loss: 0.0032 - val_mean_absolute_error: 0.0598
# Epoch 153/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 8.8760e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0032 - val_mean_absolute_error: 0.0601
# Epoch 154/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 8.8369e-04 - mean_absolute_error: 0.0278 - val_loss: 0.0034 - val_mean_absolute_error: 0.0613
# Epoch 155/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 8.8856e-04 - mean_absolute_error: 0.0285 - val_loss: 0.0036 - val_mean_absolute_error: 0.0632
# Epoch 156/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 9.3935e-04 - mean_absolute_error: 0.0305 - val_loss: 0.0033 - val_mean_absolute_error: 0.0610
# Epoch 157/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 9.2916e-04 - mean_absolute_error: 0.0305 - val_loss: 0.0035 - val_mean_absolute_error: 0.0622
# Epoch 158/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 9.6947e-04 - mean_absolute_error: 0.0302 - val_loss: 0.0030 - val_mean_absolute_error: 0.0593
# Epoch 159/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 0.0010 - mean_absolute_error: 0.0309 - val_loss: 0.0032 - val_mean_absolute_error: 0.0618
# Epoch 160/250
# 1822/1822 [==============================] - 1s 449us/step - loss: 9.6396e-04 - mean_absolute_error: 0.0308 - val_loss: 0.0033 - val_mean_absolute_error: 0.0635
# Epoch 161/250
# 1822/1822 [==============================] - 1s 450us/step - loss: 9.7510e-04 - mean_absolute_error: 0.0304 - val_loss: 0.0036 - val_mean_absolute_error: 0.0660
# Epoch 162/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 9.7086e-04 - mean_absolute_error: 0.0296 - val_loss: 0.0036 - val_mean_absolute_error: 0.0658
# Epoch 163/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0010 - mean_absolute_error: 0.0307 - val_loss: 0.0033 - val_mean_absolute_error: 0.0628
# Epoch 164/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 9.1674e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0031 - val_mean_absolute_error: 0.0612
# Epoch 165/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 8.9430e-04 - mean_absolute_error: 0.0279 - val_loss: 0.0030 - val_mean_absolute_error: 0.0587
# Epoch 166/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 8.7266e-04 - mean_absolute_error: 0.0288 - val_loss: 0.0030 - val_mean_absolute_error: 0.0589
# Epoch 167/250
# 1822/1822 [==============================] - 1s 455us/step - loss: 9.0888e-04 - mean_absolute_error: 0.0292 - val_loss: 0.0040 - val_mean_absolute_error: 0.0708
# Epoch 168/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 0.0010 - mean_absolute_error: 0.0315 - val_loss: 0.0044 - val_mean_absolute_error: 0.0752
# Epoch 169/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 0.0013 - mean_absolute_error: 0.0354 - val_loss: 0.0039 - val_mean_absolute_error: 0.0701
# Epoch 170/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 0.0010 - mean_absolute_error: 0.0319 - val_loss: 0.0034 - val_mean_absolute_error: 0.0648
# Epoch 171/250
# 1822/1822 [==============================] - 1s 423us/step - loss: 0.0010 - mean_absolute_error: 0.0313 - val_loss: 0.0038 - val_mean_absolute_error: 0.0681
# Epoch 172/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 9.9727e-04 - mean_absolute_error: 0.0322 - val_loss: 0.0034 - val_mean_absolute_error: 0.0648
# Epoch 173/250
# 1822/1822 [==============================] - 1s 423us/step - loss: 9.4983e-04 - mean_absolute_error: 0.0308 - val_loss: 0.0030 - val_mean_absolute_error: 0.0581
# Epoch 174/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 8.7739e-04 - mean_absolute_error: 0.0298 - val_loss: 0.0029 - val_mean_absolute_error: 0.0578
# Epoch 175/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 9.0569e-04 - mean_absolute_error: 0.0304 - val_loss: 0.0030 - val_mean_absolute_error: 0.0580
# Epoch 176/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 8.7116e-04 - mean_absolute_error: 0.0289 - val_loss: 0.0038 - val_mean_absolute_error: 0.0657
# Epoch 177/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 9.4202e-04 - mean_absolute_error: 0.0299 - val_loss: 0.0031 - val_mean_absolute_error: 0.0589
# Epoch 178/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 8.7782e-04 - mean_absolute_error: 0.0289 - val_loss: 0.0033 - val_mean_absolute_error: 0.0607
# Epoch 179/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 8.7257e-04 - mean_absolute_error: 0.0283 - val_loss: 0.0031 - val_mean_absolute_error: 0.0583
# Epoch 180/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 8.4724e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0031 - val_mean_absolute_error: 0.0585
# Epoch 181/250
# 1822/1822 [==============================] - 1s 445us/step - loss: 8.7351e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0030 - val_mean_absolute_error: 0.0579
# Epoch 182/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 8.6199e-04 - mean_absolute_error: 0.0281 - val_loss: 0.0030 - val_mean_absolute_error: 0.0582
# Epoch 183/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 9.0706e-04 - mean_absolute_error: 0.0311 - val_loss: 0.0029 - val_mean_absolute_error: 0.0573
# Epoch 184/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 8.1615e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0029 - val_mean_absolute_error: 0.0572
# Epoch 185/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 8.3444e-04 - mean_absolute_error: 0.0265 - val_loss: 0.0029 - val_mean_absolute_error: 0.0573
# Epoch 186/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 8.4020e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0029 - val_mean_absolute_error: 0.0581
# Epoch 187/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 8.3417e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0029 - val_mean_absolute_error: 0.0584
# Epoch 188/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 8.3580e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0031 - val_mean_absolute_error: 0.0610
# Epoch 189/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 9.8933e-04 - mean_absolute_error: 0.0326 - val_loss: 0.0030 - val_mean_absolute_error: 0.0606
# Epoch 190/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 8.8113e-04 - mean_absolute_error: 0.0296 - val_loss: 0.0030 - val_mean_absolute_error: 0.0605
# Epoch 191/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 8.7001e-04 - mean_absolute_error: 0.0279 - val_loss: 0.0030 - val_mean_absolute_error: 0.0596
# Epoch 192/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 8.4326e-04 - mean_absolute_error: 0.0269 - val_loss: 0.0031 - val_mean_absolute_error: 0.0610
# Epoch 193/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 8.9750e-04 - mean_absolute_error: 0.0290 - val_loss: 0.0030 - val_mean_absolute_error: 0.0573
# Epoch 194/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 8.4258e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0028 - val_mean_absolute_error: 0.0565
# Epoch 195/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 8.1993e-04 - mean_absolute_error: 0.0271 - val_loss: 0.0028 - val_mean_absolute_error: 0.0564
# Epoch 196/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 8.0781e-04 - mean_absolute_error: 0.0262 - val_loss: 0.0028 - val_mean_absolute_error: 0.0565
# Epoch 197/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 8.4549e-04 - mean_absolute_error: 0.0278 - val_loss: 0.0028 - val_mean_absolute_error: 0.0564
# Epoch 198/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 8.3353e-04 - mean_absolute_error: 0.0281 - val_loss: 0.0028 - val_mean_absolute_error: 0.0560
# Epoch 199/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 8.1128e-04 - mean_absolute_error: 0.0273 - val_loss: 0.0028 - val_mean_absolute_error: 0.0563
# Epoch 200/250
# 1822/1822 [==============================] - 1s 447us/step - loss: 8.3616e-04 - mean_absolute_error: 0.0289 - val_loss: 0.0027 - val_mean_absolute_error: 0.0562
# Epoch 201/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 8.3192e-04 - mean_absolute_error: 0.0286 - val_loss: 0.0029 - val_mean_absolute_error: 0.0565
# Epoch 202/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 7.9196e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0030 - val_mean_absolute_error: 0.0577
# Epoch 203/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 8.0819e-04 - mean_absolute_error: 0.0269 - val_loss: 0.0029 - val_mean_absolute_error: 0.0563
# Epoch 204/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 7.9363e-04 - mean_absolute_error: 0.0264 - val_loss: 0.0028 - val_mean_absolute_error: 0.0558
# Epoch 205/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 8.0025e-04 - mean_absolute_error: 0.0269 - val_loss: 0.0029 - val_mean_absolute_error: 0.0596
# Epoch 206/250
# 1822/1822 [==============================] - 1s 442us/step - loss: 8.6572e-04 - mean_absolute_error: 0.0275 - val_loss: 0.0027 - val_mean_absolute_error: 0.0555
# Epoch 207/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 8.2749e-04 - mean_absolute_error: 0.0280 - val_loss: 0.0034 - val_mean_absolute_error: 0.0620
# Epoch 208/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 9.0361e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0030 - val_mean_absolute_error: 0.0574
# Epoch 209/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 7.9350e-04 - mean_absolute_error: 0.0257 - val_loss: 0.0032 - val_mean_absolute_error: 0.0597
# Epoch 210/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 8.0283e-04 - mean_absolute_error: 0.0258 - val_loss: 0.0028 - val_mean_absolute_error: 0.0555
# Epoch 211/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 7.8096e-04 - mean_absolute_error: 0.0257 - val_loss: 0.0030 - val_mean_absolute_error: 0.0576
# Epoch 212/250
# 1822/1822 [==============================] - 1s 452us/step - loss: 8.0488e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0031 - val_mean_absolute_error: 0.0578
# Epoch 213/250
# 1822/1822 [==============================] - 1s 450us/step - loss: 8.4628e-04 - mean_absolute_error: 0.0295 - val_loss: 0.0029 - val_mean_absolute_error: 0.0564
# Epoch 214/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 8.5950e-04 - mean_absolute_error: 0.0299 - val_loss: 0.0028 - val_mean_absolute_error: 0.0555
# Epoch 215/250
# 1822/1822 [==============================] - 1s 439us/step - loss: 8.0301e-04 - mean_absolute_error: 0.0271 - val_loss: 0.0027 - val_mean_absolute_error: 0.0549
# Epoch 216/250
# 1822/1822 [==============================] - 1s 434us/step - loss: 8.0872e-04 - mean_absolute_error: 0.0271 - val_loss: 0.0029 - val_mean_absolute_error: 0.0568
# Epoch 217/250
# 1822/1822 [==============================] - 1s 437us/step - loss: 7.9629e-04 - mean_absolute_error: 0.0270 - val_loss: 0.0027 - val_mean_absolute_error: 0.0547
# Epoch 218/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 7.9675e-04 - mean_absolute_error: 0.0264 - val_loss: 0.0028 - val_mean_absolute_error: 0.0584
# Epoch 219/250
# 1822/1822 [==============================] - 1s 446us/step - loss: 8.3202e-04 - mean_absolute_error: 0.0277 - val_loss: 0.0028 - val_mean_absolute_error: 0.0580
# Epoch 220/250
# 1822/1822 [==============================] - 1s 426us/step - loss: 7.9429e-04 - mean_absolute_error: 0.0271 - val_loss: 0.0027 - val_mean_absolute_error: 0.0570
# Epoch 221/250
# 1822/1822 [==============================] - 1s 443us/step - loss: 8.2036e-04 - mean_absolute_error: 0.0277 - val_loss: 0.0027 - val_mean_absolute_error: 0.0558
# Epoch 222/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 8.0738e-04 - mean_absolute_error: 0.0268 - val_loss: 0.0027 - val_mean_absolute_error: 0.0566
# Epoch 223/250
# 1822/1822 [==============================] - 1s 429us/step - loss: 7.9895e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0026 - val_mean_absolute_error: 0.0544
# Epoch 224/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 7.5312e-04 - mean_absolute_error: 0.0249 - val_loss: 0.0029 - val_mean_absolute_error: 0.0568
# Epoch 225/250
# 1822/1822 [==============================] - 1s 438us/step - loss: 8.0414e-04 - mean_absolute_error: 0.0262 - val_loss: 0.0030 - val_mean_absolute_error: 0.0571
# Epoch 226/250
# 1822/1822 [==============================] - 1s 425us/step - loss: 8.0977e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0029 - val_mean_absolute_error: 0.0566
# Epoch 227/250
# 1822/1822 [==============================] - 1s 441us/step - loss: 8.0411e-04 - mean_absolute_error: 0.0259 - val_loss: 0.0027 - val_mean_absolute_error: 0.0547
# Epoch 228/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 7.6530e-04 - mean_absolute_error: 0.0254 - val_loss: 0.0027 - val_mean_absolute_error: 0.0543
# Epoch 229/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 7.8706e-04 - mean_absolute_error: 0.0265 - val_loss: 0.0028 - val_mean_absolute_error: 0.0555
# Epoch 230/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 7.9856e-04 - mean_absolute_error: 0.0261 - val_loss: 0.0026 - val_mean_absolute_error: 0.0539
# Epoch 231/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 8.1828e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0026 - val_mean_absolute_error: 0.0547
# Epoch 232/250
# 1822/1822 [==============================] - 1s 452us/step - loss: 7.5904e-04 - mean_absolute_error: 0.0256 - val_loss: 0.0027 - val_mean_absolute_error: 0.0568
# Epoch 233/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 7.8214e-04 - mean_absolute_error: 0.0267 - val_loss: 0.0026 - val_mean_absolute_error: 0.0557
# Epoch 234/250
# 1822/1822 [==============================] - 1s 428us/step - loss: 8.1317e-04 - mean_absolute_error: 0.0264 - val_loss: 0.0029 - val_mean_absolute_error: 0.0560
# Epoch 235/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 7.7341e-04 - mean_absolute_error: 0.0251 - val_loss: 0.0027 - val_mean_absolute_error: 0.0550
# Epoch 236/250
# 1822/1822 [==============================] - 1s 433us/step - loss: 7.7035e-04 - mean_absolute_error: 0.0257 - val_loss: 0.0027 - val_mean_absolute_error: 0.0544
# Epoch 237/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 7.7433e-04 - mean_absolute_error: 0.0255 - val_loss: 0.0026 - val_mean_absolute_error: 0.0537
# Epoch 238/250
# 1822/1822 [==============================] - 1s 444us/step - loss: 7.3121e-04 - mean_absolute_error: 0.0246 - val_loss: 0.0025 - val_mean_absolute_error: 0.0539
# Epoch 239/250
# 1822/1822 [==============================] - 1s 432us/step - loss: 7.3024e-04 - mean_absolute_error: 0.0245 - val_loss: 0.0026 - val_mean_absolute_error: 0.0548
# Epoch 240/250
# 1822/1822 [==============================] - 1s 435us/step - loss: 7.5334e-04 - mean_absolute_error: 0.0265 - val_loss: 0.0026 - val_mean_absolute_error: 0.0539
# Epoch 241/250
# 1822/1822 [==============================] - 1s 431us/step - loss: 7.8013e-04 - mean_absolute_error: 0.0265 - val_loss: 0.0028 - val_mean_absolute_error: 0.0555
# Epoch 242/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 7.9951e-04 - mean_absolute_error: 0.0270 - val_loss: 0.0033 - val_mean_absolute_error: 0.0610
# Epoch 243/250
# 1822/1822 [==============================] - 1s 423us/step - loss: 8.0726e-04 - mean_absolute_error: 0.0272 - val_loss: 0.0035 - val_mean_absolute_error: 0.0633
# Epoch 244/250
# 1822/1822 [==============================] - 1s 430us/step - loss: 8.6814e-04 - mean_absolute_error: 0.0282 - val_loss: 0.0031 - val_mean_absolute_error: 0.0584
# Epoch 245/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 7.8146e-04 - mean_absolute_error: 0.0274 - val_loss: 0.0029 - val_mean_absolute_error: 0.0564
# Epoch 246/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 7.5315e-04 - mean_absolute_error: 0.0258 - val_loss: 0.0031 - val_mean_absolute_error: 0.0583
# Epoch 247/250
# 1822/1822 [==============================] - 1s 427us/step - loss: 7.8039e-04 - mean_absolute_error: 0.0263 - val_loss: 0.0029 - val_mean_absolute_error: 0.0557
# Epoch 248/250
# 1822/1822 [==============================] - 1s 440us/step - loss: 7.6876e-04 - mean_absolute_error: 0.0254 - val_loss: 0.0027 - val_mean_absolute_error: 0.0546
# Epoch 249/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 7.4767e-04 - mean_absolute_error: 0.0261 - val_loss: 0.0027 - val_mean_absolute_error: 0.0549
# Epoch 250/250
# 1822/1822 [==============================] - 1s 436us/step - loss: 8.3420e-04 - mean_absolute_error: 0.0299 - val_loss: 0.0026 - val_mean_absolute_error: 0.0539

# %% [markdown]
# Once we predict the values, we also must *reverse* the normalization so that we can plot the predictions in the same scale as the original values.

# %%
y_pred_train_keras = scaler.inverse_transform(keras_model.predict(X_train_reshape, batch_size=256))
y_pred_keras = scaler.inverse_transform(keras_model.predict(X_test_reshape, batch_size=256))

# %% [markdown]
# Let's now plot what the training and test predictions look like and compare witht he original values.

# %%
# Plot what it looks like for the training data
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_keras['Adj Close Train'] = y_pred_train_keras[:-window_size]
df_keras.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again, quite accurate... and now for the test data.

# %%
# Same for the test
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_keras['Adj Close Test'] = y_pred_keras
df_keras.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# I have more confidence in the neural network approach as it seems to indicate would the trend would be like when the data is noise free.  We can also see a more smoother transition between points of high curvature.
#
# Finally to see how everything performs, let's plot all of the methods together for both the training and testing data.

# %%
df_train = df.copy()
df_train.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_train = df_train.iloc[window_size:ind_split] # Past 32 days we don't know yet
# Add in all of our methods
df_train['Adj Close Train Ridge'] = y_pred_train_ridge[:-window_size]
df_train['Adj Close Train Gradient Boosting'] = y_pred_train_gb[:-window_size]
df_train['Adj Close Train LSTM'] = y_pred_train_keras[:-window_size]
# Plot the data now
df_train.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Cool.  They all more or less follow the same trend... and now for the testing data.

# %%
df_test = df.copy()
df_test.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_test = df_test.iloc[ind_split+window_size:] # Past 32 days we don't know yet
# Add in all of our methods
df_test['Adj Close Test Ridge'] = y_pred_ridge
df_test['Adj Close Test Gradient Boosting'] = y_pred_gb
df_test['Adj Close Test LSTM'] = y_pred_keras
# Plot the data now
df_test.plot(label='TSLA', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# So here's where it gets interesting.  We can see that the neural network based method is what the values would be when there's no presence of noise.  The ridge regression based method seems to follow the trend the best with the noise modelled in.  The gradient boosting method also follows the same trend, but because the method does not use interpolation, points of very high curvature tend to be the most inaccurate.

# %% [markdown]
# # So what happens if we don't have testing data to try out?
#
# Good question.  What you can do take the learned model that you have, then start with the last $N$ values in your data (in my case 32), and start predicting what the next values will be.  With the next values, keep using the previous $N$ values for your desired forecasting.
#
# We already have our learned models above, so let's go ahead and do that.

# %%
num_days = 10 # Let's try and forecase the next 10 days or two years

# Get the last window_size (32) days
data_seed = df['Adj Close'].values[-window_size:][None]
# Get the normalized data as well for the neural network
data_seed_norm = scaler.transform(data_seed)
input_values = {"ridge": data_seed, "gb": data_seed, "keras": data_seed_norm.copy()}
values = {"ridge": [], "gb": [], "keras": []}
for i in range(num_days): # For each day...
    # Predict the next price given the previous N prices
    values["ridge"].append(ridge_model.predict(input_values["ridge"])[0])
    values["gb"].append(gb_model.predict(input_values["gb"])[0])
    values["keras"].append(keras_model.predict(input_values["keras"][...,None])[0][0])

    # Dump the oldest price and put the newest price at the end
    for v in input_values:
        val = input_values[v]
        val = np.insert(val, -1, values[v][-1], axis=1)
        val = np.delete(val, 0, axis=1)
        input_values[v] = val.copy()

# Convert all to NumPy arrays
for v in input_values:
    values[v] = np.array(values[v])

# Unnormalize prices from NN approach
values["keras"] = scaler.inverse_transform(values["keras"][None])[0]

# %% [markdown]
# Now let's plot the next 10 days worth of data

# %%
from datetime import timedelta, datetime
last_date = datetime.strptime(df.index[-1], '%Y-%m-%d')
df_forecast = pd.DataFrame()
df_forecast["Ridge"] = values["ridge"]
df_forecast["Gradient Boosting"] = values["gb"]
df_forecast["Keras LSTM"] = values["keras"]
df_forecast.index = pd.date_range(start=last_date, periods=num_days)
df_forecast.plot(label='TSLA', figsize=(16,8), title='Forecasted Adjusted Closing Price', grid=True)

# %% [markdown]
# # That's all folks!
#
# ![That's all folks!](https://media.giphy.com/media/l2R0eYcNq9rJUsVAA/giphy.gif)
